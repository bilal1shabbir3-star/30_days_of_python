# %% [markdown]
# # Date And Time in Python:

# %%
# Python has datetime module to handle date and time
import datetime
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
# Getting datetime information

from datetime import datetime

now = datetime.now()
print(now)

day = now.day
print(day)

month = now.month
print(month)

year = now.year
print(year)

hour = now.hour
print(hour)

minutes = now.min
print(minutes)

seconds = now.second
print(seconds)

timestamp = now.timestamp()
print(timestamp)

print(day, month, year, hour, minutes, seconds)
print('timestamp', timestamp)
print(f'{day}/{month}/{year}, {hour}:{minutes}')
# Out:
# 2026-09-24 17:55:50.152877
# 24
# 9
# 2026
# 17
# 0001-01-01 00:00:00
# 50
# 1790254550.152877
# 24 9 2026 17 0001-01-01 00:00:00 50
# timestamp 1790254550.152877
# 24/9/2026, 17:0001-01-01 00:00:00

# %%
# Formating Date output using the strftime

from datetime import datetime

new_year = datetime(2026, 9, 24)
print(new_year)
day = new_year.day
month = new_year.month
year = new_year.year
minut = new_year.minute
seconds = new_year.second

print('timestamp', timestamp)
print(f'{day}/{month}/{year}, {hour}:{minutes}')
# Out:
# 2026-09-24 00:00:00
# timestamp 1790254550.152877
# 24/9/2026, 17:0001-01-01 00:00:00

# %%
# Continue

from datetime import datetime

# Current  date and time

now = datetime.now()
t = now.strftime("%H:%M:%S")
print('time:', t)

time_one = now.strftime("%m/%d/%Y, %H:%M:%S")
print("TimeOne:", time_one)
# Out:
# time: 18:08:34
# TimeOne: 09/24/2026, 18:08:34

# %%
# String to time using strptime

from datetime import datetime

date_string = "24 September, 2026"
print("datetime_string =", date_string)

date_obj = datetime.strptime(date_string, "%d %B, %Y")
print("date_obj =",date_obj)
# Out:
# datetime_string = 24 September, 2026
# date_obj = 2026-09-24 00:00:00

# %%
# Using date from datetime

from datetime import date

d = date(2005, 1, 1)
print("Date =", d)

today = d.today()
print("Current_date =", today)

print("Current_year =", today.year)
print("Current_month =", today.month)
print("Current_day =", today.day)
# Out:
# Date = 2005-01-01
# Current_date = 2026-09-24
# Current_year = 2026
# Current_month = 9
# Current_day = 24
