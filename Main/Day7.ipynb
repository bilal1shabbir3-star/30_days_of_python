# %% [markdown]
# # Functions:

# %%
# Functions without parameters

def gen_full_name():
    
    first_name = "Bilal"
    last_name = "Shabbir"
    space = " "
    
    full_name = first_name + space + last_name
    
    print(full_name)
    
gen_full_name()
# Out:
# Bilal Shabbir

# %%
# Function returning a value - Part 1

def gen_full_name():
    
    first_name = "Bilal"
    last_name = "Shabbir"
    space = " "
    
    full_name = first_name + space + last_name
    
    return full_name
    
print(gen_full_name())
# Out:
# Bilal Shabbir

# %%
# Function with parameters

# Single parameter function

def greetings(name):
    
    message = name + ", Welcome to python for everyone!"
    return message

print(greetings("Bilal"))
# Out:
# Bilal, Welcome to python for everyone!

# %%
# Function with parameters

# Double parameter function

def generate_full_name(first_name, second_name):
    
    space = " "
    
    full_name = first_name + space + second_name
    
    return full_name

print(generate_full_name("Bilal", "Shabbir"))
# Out:
# Bilal Shabbir

# %%
# Passing arguments with key and value

def generate_full_name(first_name, last_name):
    
    space = " "
    
    full_name = first_name + space + last_name
    
    return full_name

print(generate_full_name(first_name="Bilal", last_name="Shabbir"))
# Out:
# Bilal Shabbir

# %%
def generate_full_name(first_name, second_name):
    
    space = " "
    
    full_name = first_name + space + second_name
    
    return full_name
print(generate_full_name("Bilal", "Shabbir"))
# Out:
# Bilal Shabbir

# %%
# returning a boolean

def is_even(num):
    if num % 2 == 0:
        return True
    else:
        return False
    
is_even(3)
# Out:
# False

# %%
# Functions with default parameters values

def is_even(num = 100):
    if num % 2 == 0:
        return True
    
    return False
    
is_even()
# Out:
# True

# %%
# Functions with arbitrary number of arguments

def sum_all_num(*num):
    total = 0
    for num in num:
        total += num
    return total
sum_all_num(2,3,4)
# Out:
# 9

# %%
# Default and Arbitrary Number of Parameters in Functions

def generate_groups(team, *names):
    print(team)
    for i in names:
        print(i)
generate_groups("MEow BIli", "Bilal", "Qosain")
# Out:
# MEow BIli
# Bilal
# Qosain

# %%
def greet(name, location):
    print("Hi",name, "How is the weather in", location)
greet("Bilal","SadiqAbad")

my_dict= {"name": "Bilal",
          "location": "Sadiqabad"}

greet(**my_dict)
# Out:
# Hi Bilal How is the weather in SadiqAbad
# Hi Bilal How is the weather in Sadiqabad

# %%
# FUnction as PArameter of ANother FUnction

def  square_num(n):
    return n * n
def do_something(f, x):
    return f(x)
do_something(square_num, 2)
# Out:
# 4
